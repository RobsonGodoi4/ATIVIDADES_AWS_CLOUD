# %% [markdown]
# <a href="https://colab.research.google.com/github/RobsonGodoi4/ATIVIDADES_AWS_CLOUD/blob/main/alterar_removerElementos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista_produtos = ['máscaras faciais', 'batons', 'esmaltes', 'perfumes', 'loções', 'xampus', 'sabonetes', 'delineadores']
lista_produtos[1], lista_produtos[4] = 'rímel', 'creme hidratante'

lista_produtos.pop()

print(lista_produtos)
# Out:
# ['máscaras faciais', 'rímel', 'esmaltes', 'perfumes', 'creme hidratante', 'xampus', 'sabonetes']
