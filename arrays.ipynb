# %% [markdown]
# <a href="https://colab.research.google.com/github/RobsonGodoi4/ATIVIDADES_AWS_CLOUD/blob/main/arrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
produtos_loja_instrumentos = ["Violão", "Teclado", "Guitarra", "Bateria", "Microfone"]

anos_nascimento = [1995, 1998, 2000, 1987, 2003]

print("Produtos da loja de instrumentos:", produtos_loja_instrumentos)
print("Anos de nascimento:", anos_nascimento)
